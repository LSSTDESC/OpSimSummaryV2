# %%
import opsimsummaryv2 as op

# %%
sql_engine = op.OpSimSurvey._get_sql_engine("/pscratch/sd/d/desctd/cfs_mirror/SNANA/SURVEYS/LSST/ROOT/simlibs/baseline_v5.3.0_10yrs.db")
# Out:
# Reading from database sqlite:////pscratch/sd/d/desctd/cfs_mirror/SNANA/SURVEYS/LSST/ROOT/simlibs/baseline_v5.3.0_10yrs.db

# %%
df = op.OpSimSurvey._get_df_from_sql(sql_engine)
# Out:
# Read N = 1844571 observations in 44.93 seconds.

# %%
df["filter"] = df["filter"].str.extract(r'([a-zA-Z]+)')

# %%
df["filter"]
# Out:
# observationId
# 0          u
# 1          u
# 2          u
# 3          u
# 4          u
#           ..
# 1844566    i
# 1844567    i
# 1844568    i
# 1844569    i
# 1844570    i
# Name: filter, Length: 1844571, dtype: object
